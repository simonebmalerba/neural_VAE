# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
from src.encoders_decoders import *

# %%
N = 50
#Define data distribution
x_data = torch.distributions.uniform.Uniform(0,1).sample((500,))[:,None]
x_sorted,indices = x_data.sort(dim=0)
x_min,x_max = x_sorted[0,:].item(),x_sorted[-1,:].item()

# %%
def distortion_gaussian(x,encoder,decoder,lat_samp=10,tau=0.5):
    #Logit r|x
    l_r_x = encoder(x)
    bsize,N = l_r_x.shape
    eps = torch.rand(bsize,lat_samp,N)
    r = torch.sigmoid((torch.log(eps) - torch.log(1-eps) + l_r_x[:,None,:])/tau)
    mu_dec,sigma2_dec = decoder(r)
    inv_sigma2_dec = 1/sigma2_dec
    mp = mu_dec*inv_sigma2_dec
    logq_x_r = -0.5*(x**2)*inv_sigma2_dec + x*mp - 0.5*mu_dec*mp - 0.5*torch.log(2*np.pi*sigma2_dec)
    D = -logq_x_r.mean()
    return D
def distortion_ideal(x,encoder,lat_samp=10,tau=0.5):
    l_r_x = encoder(x)
    bsize,N = l_r_x.shape
    eps = torch.rand(bsize,lat_samp,N)
    r = torch.sigmoid((torch.log(eps) - torch.log(1-eps) + l_r_x[:,None,:])/tau)
    lam = encoder(x).transpose(0,1)
    b = -torch.log(torch.exp(encoder(x))+1).transpose(0,1).sum(dim=0)[None,None,:]
    h = torch.softmax(r@lam + b,dim=2)
    D = torch.cat([-torch.log(h[i,:,i]) for i in range(bsize)]).mean()
    return D

# %%
dVec = []
dtVec = []
rVec = []
for sigmai in np.arange(0.01,0.2,0.01):
    enc = BernoulliEncoder(N,x_min-0.2,x_max+0.2)
    enc.log_sigmas = torch.log(sigmai*torch.ones(N)[None,:]) 
    inv_sigma2 = torch.exp(-2*enc.log_sigmas).transpose(0,1)
    phi0 = torch.cat((enc.cs.transpose(0,1)*inv_sigma2,-0.5*inv_sigma2),dim=1)
    dec = GaussianDecoder(phi0)
    dVec.append(distortion_gaussian(x_sorted,enc,dec,tau=0.1).item())
    dtVec.append(distortion_ideal(x_sorted,enc,tau=0.1).item())
    l_r_x = enc(x_sorted)
    #Dkl between two bernoulli distributions
    r = (torch.sigmoid(l_r_x)*(F.logsigmoid(l_r_x) - np.log(0.1)) + torch.sigmoid(-l_r_x)*(F.logsigmoid(-l_r_x) - np.log(0.1))).sum(dim=1).mean()
    rVec.append(r.item())

# %%
enc = BernoulliEncoder(N,x_min-0.2,x_max+0.2)
lat_samp=10
tau=0.1
enc.log_sigmas = torch.log(0.01*torch.ones(N)[None,:]) 
inv_sigma2 = torch.exp(-2*enc.log_sigmas).transpose(0,1)
phi0 = torch.cat((enc.cs.transpose(0,1)*inv_sigma2,-0.5*inv_sigma2),dim=1)
dec = GaussianDecoder(phi0)
p_r_x = enc(x_sorted)
bsize,N = p_r_x.shape
eps = torch.rand(bsize,lat_samp,N)
r = torch.sigmoid((torch.log(eps) - torch.log(1-eps) + p_r_x[:,None,:])/tau)
mu_dec,sigma2_dec = dec(r)
inv_sigma2_dec = 1/sigma2_dec
mp = mu_dec*inv_sigma2_dec
logq_x_r = -0.5*(x_sorted**2)*inv_sigma2_dec + x_sorted*mp - 0.5*mu_dec*mp - 0.5*torch.log(2*np.pi*sigma2_dec)
logq_x_r.mean()
# Out:
# tensor(0.7158, grad_fn=<MeanBackward0>)

# %%
plt.plot(np.arange(0.01,0.2,0.01),dVec + np.log(500),np.arange(0.01,0.2,0.01),dtVec,
np.arange(0.01,0.2,0.01),rVec)
# Out:
# [<matplotlib.lines.Line2D at 0x7fb21ec7e460>,
#  <matplotlib.lines.Line2D at 0x7fb21ec7e670>,
#  <matplotlib.lines.Line2D at 0x7fb21ec7eeb0>]

# %%
with torch.no_grad():
    nsample =[1,3,5,7]
    fig,(ax1,ax2) = plt.subplots(2)
    q_x_r = torch.exp(torch.distributions.normal.Normal(mu_dec[200,nsample],torch.sqrt(sigma2_dec[200,nsample])).log_prob(x_sorted))
    ax1.plot(range(N),r[200,nsample,:].transpose(0,1))
    ax2.plot(x_sorted,q_x_r)
    #plt.show()

# %%
l_r_x = enc(x_sorted)
#Dkl between two bernoulli distributions
torch.sigmoid(l_r_x)*(F.logsigmoid(l_r_x) - np.log(0.01)) + torch.sigmoid(-l_r_x)*(F.logsigmoid(-l_r_x) - np.log(0.01))
# Out:
# tensor([[4.6052, 4.6052, 4.6052,  ..., 4.6052, 4.6052, 4.6052],
#         [4.6052, 4.6052, 4.6052,  ..., 4.6052, 4.6052, 4.6052],
#         [4.6052, 4.6052, 4.6052,  ..., 4.6052, 4.6052, 4.6052],
#         ...,
#         [4.6052, 4.6052, 4.6052,  ..., 4.6052, 4.6052, 4.6052],
#         [4.6052, 4.6052, 4.6052,  ..., 4.6052, 4.6052, 4.6052],
#         [4.6052, 4.6052, 4.6052,  ..., 4.6052, 4.6052, 4.6052]],
#        grad_fn=<AddBackward0>)

# %%
q_r = enc(x_sorted[idx]).transpose(0,1)[None,:,:]
l_r_x = torch.sigmoid(enc(x_sorted))[:,:,None]
torch.sigmoid(l_r_x)*(F.logsigmoid(l_r_x) - np.log(0.01)) + torch.sigmoid(-l_r_x)*(F.logsigmoid(-l_r_x) - np.log(0.01))

# %%
p_r_x[:,:,None]
# Out:
# tensor([[[2.3650e+07, 1.3560e+04, 5.9283e+00,  ..., 1.0833e+05,
#           7.2165e+01, 9.0468e+00],
#          [1.0821e+07, 7.6337e+03, 4.7606e+00,  ..., 5.7225e+04,
#           4.9598e+01, 7.0244e+00],
#          [4.9724e+06, 4.3162e+03, 3.8630e+00,  ..., 3.0362e+04,
#           3.4289e+01, 5.5068e+00],
#          ...,
#          [8.9714e-08, 5.6368e-07, 1.2506e-03,  ..., 2.4807e-07,
#           2.8833e-05, 5.4948e-04],
#          [4.1042e-08, 3.2894e-07, 1.0358e-03,  ..., 1.3346e-07,
#           2.0862e-05, 4.4301e-04],
#          [1.8734e-08, 1.9287e-07, 8.5796e-04,  ..., 7.2262e-08,
#           1.5098e-05, 3.5717e-04]],
#
#         [[2.3556e+07, 1.3506e+04, 5.9047e+00,  ..., 1.0790e+05,
#           7.1877e+01, 9.0108e+00],
#          [1.0786e+07, 7.6090e+03, 4.7451e+00,  ..., 5.7040e+04,
#           4.9437e+01, 7.0016e+00],
#          [4.9596e+06, 4.3051e+03, 3.8530e+00,  ..., 3.0283e+04,
#           3.4200e+01, 5.4925e+00],
#          ...,
#          [9.2891e-08, 5.8365e-07, 1.2949e-03,  ..., 2.5686e-07,
#           2.9854e-05, 5.6894e-04],
#          [4.2533e-08, 3.4089e-07, 1.0735e-03,  ..., 1.3831e-07,
#           2.1620e-05, 4.5910e-04],
#          [1.9431e-08, 2.0005e-07, 8.8991e-04,  ..., 7.4952e-08,
#           1.5661e-05, 3.7047e-04]],
#
#         [[2.3435e+07, 1.3437e+04, 5.8743e+00,  ..., 1.0734e+05,
#           7.1508e+01, 8.9645e+00],
#          [1.0740e+07, 7.5771e+03, 4.7252e+00,  ..., 5.6801e+04,
#           4.9230e+01, 6.9722e+00],
#          [4.9430e+06, 4.2907e+03, 3.8401e+00,  ..., 3.0182e+04,
#           3.4085e+01, 5.4742e+00],
#          ...,
#          [9.7114e-08, 6.1018e-07, 1.3537e-03,  ..., 2.6853e-07,
#           3.1211e-05, 5.9480e-04],
#          [4.4516e-08, 3.5679e-07, 1.1235e-03,  ..., 1.4475e-07,
#           2.2628e-05, 4.8050e-04],
#          [2.0360e-08, 2.0961e-07, 9.3244e-04,  ..., 7.8535e-08,
#           1.6409e-05, 3.8817e-04]],
#
#         ...,
#
#         [[1.6816e-01, 9.6417e-05, 4.2151e-08,  ..., 7.7025e-04,
#           5.1311e-07, 6.4325e-08],
#          [1.7549e-01, 1.2380e-04, 7.7205e-08,  ..., 9.2806e-04,
#           8.0437e-07, 1.1392e-07],
#          [1.8313e-01, 1.5897e-04, 1.4227e-07,  ..., 1.1182e-03,
#           1.2628e-06, 2.0281e-07],
#          ...,
#          [1.1365e+00, 7.1406e+00, 1.5842e+04,  ..., 3.1425e+00,
#           3.6525e+02, 6.9607e+03],
#          [1.1739e+00, 9.4089e+00, 2.9628e+04,  ..., 3.8173e+00,
#           5.9673e+02, 1.2671e+04],
#          [1.2173e+00, 1.2532e+01, 5.5750e+04,  ..., 4.6955e+00,
#           9.8108e+02, 2.3208e+04]],
#
#         [[1.6685e-01, 9.5668e-05, 4.1824e-08,  ..., 7.6427e-04,
#           5.0913e-07, 6.3826e-08],
#          [1.7416e-01, 1.2286e-04, 7.6620e-08,  ..., 9.2103e-04,
#           7.9827e-07, 1.1306e-07],
#          [1.8178e-01, 1.5779e-04, 1.4122e-07,  ..., 1.1099e-03,
#           1.2535e-06, 2.0131e-07],
#          ...,
#          [1.1369e+00, 7.1436e+00, 1.5849e+04,  ..., 3.1438e+00,
#           3.6540e+02, 6.9636e+03],
#          [1.1746e+00, 9.4140e+00, 2.9644e+04,  ..., 3.8194e+00,
#           5.9706e+02, 1.2678e+04],
#          [1.2181e+00, 1.2541e+01, 5.5788e+04,  ..., 4.6987e+00,
#           9.8175e+02, 2.3224e+04]],
#
#         [[1.5854e-01, 9.0900e-05, 3.9740e-08,  ..., 7.2618e-04,
#           4.8375e-07, 6.0644e-08],
#          [1.6567e-01, 1.1688e-04, 7.2888e-08,  ..., 8.7617e-04,
#           7.5939e-07, 1.0755e-07],
#          [1.7313e-01, 1.5028e-04, 1.3450e-07,  ..., 1.0571e-03,
#           1.1939e-06, 1.9174e-07],
#          ...,
#          [1.1401e+00, 7.1632e+00, 1.5892e+04,  ..., 3.1524e+00,
#           3.6640e+02, 6.9827e+03],
#          [1.1787e+00, 9.4474e+00, 2.9750e+04,  ..., 3.8330e+00,
#           5.9918e+02, 1.2723e+04],
#          [1.2236e+00, 1.2597e+01, 5.6036e+04,  ..., 4.7197e+00,
#           9.8613e+02, 2.3328e+04]]], grad_fn=<DivBackward0>)

# %%
A = torch.tensor([[1.,1.],[2.,2.],[3.,3.]])
B = torch.tensor([[2.,2.],[3.,3.]]).transpose(0,1)[None,:,:]

# %%
C = A[:,:,None]/B

# %%
list(dec.parameters())
# Out:
# [Parameter containing:
#  tensor([[-1993.9492, -5000.0005],
#          [-1714.8837, -5000.0005],
#          [-1435.8182, -5000.0005],
#          [-1156.7527, -5000.0005],
#          [ -877.6873, -5000.0005],
#          [ -598.6218, -5000.0005],
#          [ -319.5563, -5000.0005],
#          [  -40.4908, -5000.0005],
#          [  238.5747, -5000.0005],
#          [  517.6401, -5000.0005],
#          [  796.7056, -5000.0005],
#          [ 1075.7711, -5000.0005],
#          [ 1354.8365, -5000.0005],
#          [ 1633.9021, -5000.0005],
#          [ 1912.9674, -5000.0005],
#          [ 2192.0330, -5000.0005],
#          [ 2471.0984, -5000.0005],
#          [ 2750.1641, -5000.0005],
#          [ 3029.2292, -5000.0005],
#          [ 3308.2947, -5000.0005],
#          [ 3587.3604, -5000.0005],
#          [ 3866.4258, -5000.0005],
#          [ 4145.4912, -5000.0005],
#          [ 4424.5566, -5000.0005],
#          [ 4703.6226, -5000.0005],
#          [ 4982.6875, -5000.0005],
#          [ 5261.7529, -5000.0005],
#          [ 5540.8184, -5000.0005],
#          [ 5819.8843, -5000.0005],
#          [ 6098.9497, -5000.0005],
#          [ 6378.0151, -5000.0005],
#          [ 6657.0806, -5000.0005],
#          [ 6936.1460, -5000.0005],
#          [ 7215.2114, -5000.0005],
#          [ 7494.2769, -5000.0005],
#          [ 7773.3423, -5000.0005],
#          [ 8052.4082, -5000.0005],
#          [ 8331.4736, -5000.0005],
#          [ 8610.5391, -5000.0005],
#          [ 8889.6045, -5000.0005],
#          [ 9168.6699, -5000.0005],
#          [ 9447.7354, -5000.0005],
#          [ 9726.8008, -5000.0005],
#          [10005.8662, -5000.0005],
#          [10284.9316, -5000.0005],
#          [10563.9971, -5000.0005],
#          [10843.0625, -5000.0005],
#          [11122.1279, -5000.0005],
#          [11401.1934, -5000.0005],
#          [11680.2598, -5000.0005]], requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0000e+00, -1.0000e-07], requires_grad=True)]
