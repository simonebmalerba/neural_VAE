# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
import pickle
import itertools
import random
from src.encoders_decoders import *
from src.losses import *
from src.useful_functions import *
from torch.utils.data import DataLoader

# %%
datadir = os.getcwd() + "/data"
files = os.listdir(datadir)
print(files)
# Out:
# ['LN_prior_N=10_q=bernoulli.pt', 'LN_prior_N=12_q=Ising.pt', 'LN_prior_N=10_q=Ising.pt', 'try_ln.pt']

# %%
data = torch.load(os.path.join(datadir,files[1]))

# %%
R_vec = list(data.keys())
data_R = data[R_vec[15]]
history_03 = data_R['history']
x_test_03 = data_R['x_test']
q_03 = data_R['q']
enc_03 = data_R['encode']
dec_03 = data_R['decoder']
enc = BernoulliEncoder(12,0,1,x_test_03,w=2) 
dec = MLPDecoder2n(12,100)
enc.load_state_dict(enc_03)
dec.load_state_dict(dec_03)
# Out:
# <All keys matched successfully>

# %%
fig,ax = training_plots(history_03["loss"],history_03["distortion"],history_03["rate"],history_03["beta"])
ax[1].set_ylim(0,10)
# Out:
# (0.0, 10.0)

# %%
fig,axs = encoder_plots(enc,x_test_03)
#axs[0].set_xscale("log")

# %%
fig,axs = decoder_plots(enc,dec,x_test_03)

# %%
with torch.no_grad():
    plt.scatter(enc.cs, torch.exp(enc.log_sigmas))

# %%
R_vec = data.keys()
Rs = []
Ds = []
bs = []
for R in R_vec:
    history_temp = data[R]['history']
    Ds.append(history_temp["distortion"][-1])
    Rs.append(history_temp["rate"][-1])
    bs.append(history_temp["beta"][-1])

# %%
plt.plot(Rs,Ds)
plt.plot( np.linspace(0,2.41),2.41 - np.linspace(0,2.41))

# %%
plt.plot(Rs,Ds)
plt.plot( np.linspace(0,2.41),2.41 - np.linspace(0,2.41))

# %%
be = torch.logspace(0, 2,steps=50)
hist, be = torch.histogram(x_test_03,be)
plt.plot(be[0:-1],hist)

# %%
porcoddio
aaa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_103215/3056512214.py in <module>
# ----> 1 porcoddio
#       2 aaa
#
# NameError: name 'porcoddio' is not defined
