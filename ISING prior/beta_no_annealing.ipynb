# %%
cd ..
# Out:
# c:\Users\auror\New_VAES\VAEs

# %%
import torch
import math
import numpy
import matplotlib.pyplot as plt
import torch.nn.functional as F
from src.encoders_decoders import *
from src.losses import *
from torch.utils.data import DataLoader
import itertools
import scipy.stats
import scipy
import random
from src.useful_functions import *

# %%
#Architecture parameters and distributions of stimuli
N = 10
K = 10
mix = torch.distributions.categorical.Categorical(torch.ones(2))
compo = torch.distributions.von_mises.VonMises(torch.tensor([-2.5,2.5]), torch.tensor([6,6]))
#p_x = torch.distributions.mixture_same_family.MixtureSameFamily(mix, compo)
p_x = torch.distributions.von_mises.VonMises(0,1)

#Training parameters
N_EPOCHS = 5000
N_SAMPLES = 5000
lr = 1e-2
BATCH_SIZE = 500

#Generate samples
x_samples = p_x.sample((N_SAMPLES,))[:,None]
x_sorted,indices = x_samples.sort(dim=0)
x_min,x_max = x_sorted[0,:].item(),x_sorted[-1,:].item()
x_data = torch.utils.data.DataLoader(x_samples,batch_size=BATCH_SIZE)
x_fine = torch.linspace(x_min,x_max,1000)[:,None]

r_all = np.asarray(list(itertools.product([0, 1], repeat=N)))

# %%
#probability density distribution
plot_pdf(x_samples)

# %%
#CIRCULAR ENCODER
enc_circ = CircularBernoulliEncoder(N,x_sorted)
dec = MLPDecoder_circ(N,200)
r = enc_circ.sample(x_fine,100)

plot_enc(enc_circ,x_sorted)

# %% [markdown]
# FULL TRAINING

# %%
#Definition of the loss elements
q = rate_ising(N)
rate = q(enc_circ,x_sorted)
dist = distortion_analytical_circular(x_sorted,enc_circ,dec,r_all)

# %%
q.J.register_hook(lambda grad: grad.fill_diagonal_(0))
params = itertools.chain(dec.parameters(), enc_circ.parameters(),q.parameters())
lr = 1e-4
opt = torch.optim.Adam(params,lr)
lossVec = []
rateVec = []
distVec = []
for epoch in range(N_EPOCHS):
    for x_ in x_data:
       rate = q(enc_circ,x_)
       dist = distortion_circular(x_,enc_circ,dec)
       loss = dist + rate 
       opt.zero_grad()
       loss.backward()
       opt.step()
    lossVec.append(loss.item())
    rateVec.append(rate.item())
    distVec.append(dist.item())

# %%
#ENCODING
plot_enc(enc_circ, x_sorted)

# %%
#neurons activity through stimulus space
plot_r(enc_circ, x_fine)

# %%
#LOSS
plot_loss(lossVec, distVec, rateVec)

# %%
plt.plot(rateVec, distVec)

# %%
#DECODING

#variance of the decoder through the stimulus space
plot_var_dec(enc_circ, dec, x_fine)

# %%
#decoder mu through stimulus space
plot_mu_dec(enc_circ,dec,x_fine)

# %%
#Mean squared error
plot_mse(enc_circ, dec, x_fine)

# %%
x_samples=generative_model(q,dec)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-0ef2b070b542> in <module>
# ----> 1 x_samples=generative_model(q,dec)
#
# c:\Users\auror\New_VAES\VAEs\src\useful_functions.py in generative_model(rate, dec)
#     136     #sampling from q(x)
#     137     N_SAMPLES=5000
# --> 138     x_samples = q_x.sample((N_SAMPLES,))[:,None]
#     139     x_samples = torch.squeeze(x_samples)
#     140
#
# ~\anaconda3\lib\site-packages\torch\distributions\mixture_same_family.py in sample(self, sample_shape)
#     165
#     166             # component samples [n, B, k, E]
# --> 167             comp_samples = self.component_distribution.sample(sample_shape)
#     168
#     169             # Gather along the k dimension
#
# ~\anaconda3\lib\site-packages\torch\distributions\independent.py in sample(self, sample_shape)
#      83
#      84     def sample(self, sample_shape=torch.Size()):
# ---> 85         return self.base_dist.sample(sample_shape)
#      86
#      87     def rsample(self, sample_shape=torch.Size()):
#
# ~\anaconda3\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~\anaconda3\lib\site-packages\torch\distributions\von_mises.py in sample(self, sample_shape)
#     112         shape = self._extended_shape(sample_shape)
#     113         x = torch.empty(shape, dtype=self.loc.dtype, device=self.loc.device)
# --> 114         return _rejection_sample(self.loc, self.concentration, self._proposal_r, x)
#     115
#     116     def expand(self, batch_shape):
#
# ~\anaconda3\lib\site-packages\torch\jit\_trace.py in wrapper(*args, **kwargs)
#    1089         if not is_tracing():
#    1090             # Not tracing, don't do anything
# -> 1091             return fn(*args, **kwargs)
#    1092
#    1093         compiled_fn = script(wrapper.__original_fn)  # type: ignore
#
# ~\anaconda3\lib\site-packages\torch\distributions\von_mises.py in _rejection_sample(loc, concentration, proposal_r, x)
#      54     done = torch.zeros(x.shape, dtype=torch.bool, device=loc.device)
#      55     while not done.all():
# ---> 56         u = torch.rand((3,) + x.shape, dtype=loc.dtype, device=loc.device)
#      57         u1, u2, u3 = u.unbind()
#      58         z = torch.cos(math.pi * u1)
#
# KeyboardInterrupt:

# %%
kde = scipy.stats.gaussian_kde(x_samples)
t_range = np.linspace(-5,5,200)
plt.plot(t_range,kde(t_range))
plt.xlabel("stimulus")
plt.ylabel("pdf")

#TRAINING THE ENCODER
# Out:
# Text(0, 0.5, 'pdf')
