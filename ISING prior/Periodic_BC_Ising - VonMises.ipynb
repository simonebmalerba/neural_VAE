# %%
cd ..
# Out:
# c:\Users\auror\New_VAES\VAEs

# %%
import torch
import math
import matplotlib.pyplot as plt
import torch.nn.functional as F
from src.encoders_decoders import *
from src.losses import *
from torch.utils.data import DataLoader
import itertools
import random
from src.useful_functions import *

# %%
#Architecture parameters and distributions of stimuli
N = 10
K = 10
#p_x = torch.distributions.uniform.Uniform(-math.pi,math.pi)
p_x = torch.distributions.von_mises.VonMises(0,2)

#Training parameters
N_EPOCHS = 100
N_SAMPLES = 5000
lr = 1e-2
BATCH_SIZE = 500

#Generate samples
x_samples = p_x.sample((N_SAMPLES,))[:,None]
x_sorted,indices = x_samples.sort(dim=0)
x_min,x_max = x_sorted[0,:].item(),x_sorted[-1,:].item()
x_data = torch.utils.data.DataLoader(x_samples,batch_size=BATCH_SIZE)
x_fine = torch.linspace(x_min,x_max,1000)[:,None]
x_samples.type
# Out:
# <function Tensor.type>

# %%
#CIRCULAR ENCODER
enc_circ = CircularBernoulliEncoder(N)
dec = MLPDecoder_circ(N,200)
r = enc_circ.sample(x_fine,100)
r_all = np.asarray(list(itertools.product([0, 1], repeat=N)))
r_all = torch.tensor(r_all).transpose(0,1).type(torch.float)

plt.plot(x_fine,torch.sigmoid(enc_circ(x_fine)).detach())
plt.xlabel("Stimulus")
plt.ylabel("Encoding")
# Out:
# Text(0, 0.5, 'Encoding')

# %%
#Modified Bessel function (to compute distortion)

class ModifiedBessel(torch.autograd.Function):
    @staticmethod
    def forward(ctx, k, nu):
        ctx._nu = nu
        ctx.save_for_backward(k)
        return torch.from_numpy(scipy.special.iv(nu, k.detach().numpy()))
    @staticmethod
    def backward(ctx, grad_out):
        k, = ctx.saved_tensors
        nu = ctx._nu
        
        return 0.5* grad_out *(ModifiedBessel.apply(k, nu - 1.0)+ModifiedBessel.apply(k, nu + 1.0)), None

modified_bessel = ModifiedBessel.apply


#Circular distortion

def distortion_circular(x,encoder,decoder,lat_samp=10,tau=0.5):
    #Logit r|x
    l_r_x = encoder(x)
    bsize,N = l_r_x.shape
    #ALERT: Gumbel Softmax trick (TO DEEPEN ALSO FOR THE THESIS)
    eps = torch.rand(bsize,lat_samp,N)
    r = torch.sigmoid((torch.log(eps) - torch.log(1-eps) + l_r_x[:,None,:])/tau)
    mu_dec,log_k = decoder(r)
    #log_k =2.29*torch.ones(1)
    #k = 1/sigma2_dec
    logq_x_r = torch.exp(log_k)*torch.cos(x-mu_dec) - torch.log(modified_bessel(torch.exp(log_k),0)) - torch.log(2*torch.as_tensor(math.pi))
    D = -logq_x_r.mean()
    return D

# %%
q = rate_ising(N)
rate = q(enc_circ,x_fine)
dist = distortion_circular(x_fine,enc_circ,dec)

# %%
q.J.register_hook(lambda grad: grad.fill_diagonal_(0))
params = itertools.chain(dec.parameters(), enc_circ.parameters(), q.parameters())
lr = 1e-3
opt = torch.optim.Adam(params,lr)
lossVec = []
rateVec = []
distVec = []
for epoch in range(5000):
    rate = q(enc_circ,x_fine)
    dist = distortion_circular(x_fine,enc_circ,dec)
    loss = dist + rate
    #print(enc_circ.log_ks)
    opt.zero_grad()
    loss.backward()
    opt.step()
    lossVec.append(loss.item())
    rateVec.append(rate.item())
    distVec.append(dist.item())

# %%
plt.plot(x_fine,torch.sigmoid(enc_circ(x_fine)).detach())
plt.xlabel("Stimulus")
plt.ylabel("Encoding")
#plt.xlim(-math.pi, math.pi)
# Out:
# Text(0, 0.5, 'Encoding')

# %%
plt.plot(rateVec, distVec)
plt.xlabel("Rate")
plt.ylabel("Distortion")
# Out:
# Text(0, 0.5, 'Distortion')

# %%
r = enc_circ.sample(x_sorted,50)
x_dec = dec.sample(r,50)
mseVec = 2 - 2*torch.cos((x_dec - x_sorted[None,:])).mean(dim=(0,2))

fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(lossVec)
axs[0, 0].set_title('Loss')
axs[0, 0].set_xlabel('epochs')
axs[0, 1].plot(rateVec)
axs[0, 1].set_title('Rate')
axs[0, 1].set_xlabel('epochs')
axs[1, 0].plot(distVec)
axs[1, 0].set_title('Distortion')
axs[1, 0].set_xlabel('epochs')
axs[1, 1].plot(x_sorted,mseVec)
axs[1, 1].set_title('MSE')
axs[1, 1].set_xlabel('x')
fig.tight_layout()
# Out:
# c:\Users\auror\New_VAES\VAEs\src\encoders_decoders.py:271: UserWarning: Output 0 of SqueezeBackward0 is a view and is being modified inplace. This view is an output of a function that returns multiple views. Inplace operators on such views are being deprecated and will be forbidden starting from version 1.8. Consider using `unsafe_` version of the function that produced this view or don't modify this view inplace. (Triggered internally at  ..\torch\csrc\autograd\variable.cpp:547.)
#   log_k_dec[log_k_dec<0] = torch.sqrt(log_k_dec[log_k_dec<0]**2)

# %%
x_dec.shape
x_sorted.shape
a = 2 - 2*torch.cos((x_dec - x_sorted[None,:])).mean(dim=(0,2))
b = 2 - 2*torch.cos((x_dec - x_sorted[None,:]).mean(dim=(0,2)))
a.shape
b.shape
# Out:
# torch.Size([5000])

# %%
r= enc_circ.sample(x_fine,50)
mu_dec,log_k_dec = dec(r)
x_ext = dec.sample(r,50)
log_k_dec
x_ext
# Out:
# c:\Users\auror\New_VAES\VAEs\src\encoders_decoders.py:271: UserWarning: Output 0 of SqueezeBackward0 is a view and is being modified inplace. This view is an output of a function that returns multiple views. Inplace operators on such views are being deprecated and will be forbidden starting from version 1.8. Consider using `unsafe_` version of the function that produced this view or don't modify this view inplace. (Triggered internally at  ..\torch\csrc\autograd\variable.cpp:547.)
#   log_k_dec[log_k_dec<0] = torch.sqrt(log_k_dec[log_k_dec<0]**2)
# tensor([[[-2.0335e-01, -4.5657e-01,  7.0000e-03,  ..., -2.0285e+00,
#           -6.1457e-01, -2.0777e-01],
#          [ 3.6974e-01,  2.8565e-01, -1.8584e+00,  ..., -1.4868e+00,
#           -1.8666e+00, -5.7815e-02],
#          [ 1.9254e+00,  6.6803e-01, -1.2874e+00,  ...,  3.8593e-01,
#           -1.2157e-01, -1.2769e+00],
#          [ 3.6776e-01, -1.5762e+00, -1.3780e+00,  ..., -1.4230e+00,
#           -1.9482e+00, -4.9731e-01],
#          [-3.5905e-01,  3.2416e-01, -1.8917e+00,  ...,  1.6368e+00,
#           -1.8206e+00, -1.5433e+00],
#          ...,
#          [ 1.9688e+00,  1.5799e+00,  1.7120e+00,  ...,  1.5480e+00,
#            2.3483e-02,  1.5808e+00],
#          [ 2.7095e-01,  1.3848e-01, -2.5604e-01,  ..., -9.7554e-02,
#           -7.6507e-01, -8.2274e-01],
#          [ 1.4888e+00,  4.2448e-01,  1.8361e-02,  ...,  1.4332e+00,
#            1.5533e+00, -7.9875e-02]],
#
#         [[-1.1434e-01,  2.0752e-01,  3.6952e-01,  ..., -1.3457e+00,
#           -1.8504e-01,  4.3447e-01],
#          [-5.4968e-01, -5.1589e-01, -1.7239e+00,  ..., -2.0067e+00,
#           -1.7835e+00, -4.6538e-01],
#          [-1.1913e-01, -1.6085e-01, -1.9839e+00,  ..., -4.2954e-01,
#           -2.2694e+00, -1.4385e+00],
#          ...,
#          [ 1.7104e+00,  1.4961e+00,  1.6373e+00,  ...,  1.7229e+00,
#            2.3391e-02,  1.5970e+00],
#          [ 4.6164e-01, -7.8546e-01,  1.2884e-01,  ...,  1.9341e-01,
#           -1.8758e-01,  4.5915e-01],
#          [ 1.6935e+00, -7.4678e-01, -7.1722e-01,  ...,  1.1616e+00,
#            1.6130e+00,  1.5806e-01]]])

# %%
#variance of the decoder through the stimulus space
with torch.no_grad():
    plt.plot(x_fine,torch.exp(log_k_dec).mean(dim=1).detach())
    plt.ylabel("var")
    plt.xlabel("Stimulus")
    plt.xlim(-math.pi,math.pi)

# %%
#Probability of each neuron to be active. The x axis is the stimulus space
plt.plot(x_fine,r.sum(dim=2).mean(dim=1))
plt.ylabel("r")
plt.xlabel("Stimulus")
plt.xlim(-math.pi,math.pi)
# Out:
# (-3.141592653589793, 3.141592653589793)

# %%
#Mean squared error

r = enc_circ.sample(x_sorted,100)
x_dec = dec.sample(r,100)


mseVec = 2 - 2*torch.cos((x_dec - x_sorted[None,:])).mean(dim=(0,2))
plt.plot(x_sorted,mseVec.detach()/20)
plt.ylabel("MSE")
plt.xlabel("Stimulus")
plt.xlim(-math.pi,math.pi)
# Out:
# c:\Users\auror\New_VAES\VAEs\src\encoders_decoders.py:271: UserWarning: Output 0 of SqueezeBackward0 is a view and is being modified inplace. This view is an output of a function that returns multiple views. Inplace operators on such views are being deprecated and will be forbidden starting from version 1.8. Consider using `unsafe_` version of the function that produced this view or don't modify this view inplace. (Triggered internally at  ..\torch\csrc\autograd\variable.cpp:547.)
#   log_k_dec[log_k_dec<0] = torch.sqrt(log_k_dec[log_k_dec<0]**2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-4f3fe0a9d744> in <module>
#       2
#       3 r = enc_circ.sample(x_sorted,100)
# ----> 4 x_dec = dec.sample(r,100)
#       5
#       6
#
# c:\Users\auror\New_VAES\VAEs\src\encoders_decoders.py in sample(self, r, dec_samples)
#     271         log_k_dec[log_k_dec<0] = torch.sqrt(log_k_dec[log_k_dec<0]**2)
#     272         q_x_r = torch.distributions.von_mises.VonMises(mu_dec, torch.exp(log_k_dec))
# --> 273         x_dec = q_x_r.sample((dec_samples,))
#     274         return x_dec
#     275
#
# ~\anaconda3\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~\anaconda3\lib\site-packages\torch\distributions\von_mises.py in sample(self, sample_shape)
#     112         shape = self._extended_shape(sample_shape)
#     113         x = torch.empty(shape, dtype=self.loc.dtype, device=self.loc.device)
# --> 114         return _rejection_sample(self.loc, self.concentration, self._proposal_r, x)
#     115
#     116     def expand(self, batch_shape):
#
# ~\anaconda3\lib\site-packages\torch\jit\_trace.py in wrapper(*args, **kwargs)
#    1089         if not is_tracing():
#    1090             # Not tracing, don't do anything
# -> 1091             return fn(*args, **kwargs)
#    1092
#    1093         compiled_fn = script(wrapper.__original_fn)  # type: ignore
#
# ~\anaconda3\lib\site-packages\torch\distributions\von_mises.py in _rejection_sample(loc, concentration, proposal_r, x)
#      61         accept = ((c * (2 - c) - u2) > 0) | ((c / u2).log() + 1 - c >= 0)
#      62         if accept.any():
# ---> 63             x = torch.where(accept, (u3 - 0.5).sign() * f.acos(), x)
#      64             done = done | accept
#      65     return (x + math.pi + loc) % (2 * math.pi) - math.pi
#
# KeyboardInterrupt:

# %%
l_r_x = enc_circ(x_fine)
bsize,N = l_r_x.shape
#ALERT: Gumbel Softmax trick (TO DEEPEN ALSO FOR THE THESIS)
eps = torch.rand(bsize,15,N)
r = torch.sigmoid((torch.log(eps) - torch.log(1-eps) + l_r_x[:,None,:])/0.1)
mu_dec,log_k = dec(r)
log_k =2.29*torch.ones(1)
logq_x_r = torch.exp(log_k)*torch.cos(x_fine-mu_dec[0,:]) - torch.log(modified_bessel(torch.exp(log_k),0)) - torch.log(2*torch.as_tensor(math.pi))

# %%
plt.plot(torch.exp(logq_x_r.detach()))
# Out:
# [<matplotlib.lines.Line2D at 0x1b117fee3d0>,
#  <matplotlib.lines.Line2D at 0x1b117fee1f0>,
#  <matplotlib.lines.Line2D at 0x1b117feeca0>,
#  <matplotlib.lines.Line2D at 0x1b1183a33d0>,
#  <matplotlib.lines.Line2D at 0x1b1183a3bb0>,
#  <matplotlib.lines.Line2D at 0x1b1183a3d30>,
#  <matplotlib.lines.Line2D at 0x1b1183a3fa0>,
#  <matplotlib.lines.Line2D at 0x1b1183a3520>,
#  <matplotlib.lines.Line2D at 0x1b1183a3550>,
#  <matplotlib.lines.Line2D at 0x1b1183a3670>,
#  <matplotlib.lines.Line2D at 0x1b11800e4c0>,
#  <matplotlib.lines.Line2D at 0x1b1183a37c0>,
#  <matplotlib.lines.Line2D at 0x1b118009c70>,
#  <matplotlib.lines.Line2D at 0x1b118009e20>,
#  <matplotlib.lines.Line2D at 0x1b118009b50>]

# %%
plt.plot(mu_dec.mean(dim=1).detach())
